# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
df_exams['gender'].head
# Out:
# <bound method NDFrame.head of 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object>

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
#selecting two or more columns

df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams[['gender', 'math score', 'reading score', 'writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
#we cannot select 2 or more columns with a dot

# %%
#add a column

df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %%
import numpy as np

# %%
language_score = np.arange(0, 1000)
len(language_score)
# Out:
# 1000

# %%
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score
# 0                 0               0
# 1                 1               1
# 2                 2               2
# 3                 3               3
# 4                 4               4
# ..              ...             ...
# 995             995             995
# 996             996             996
# 997             997             997
# 998             998             998
# 999             999             999
#
# [1000 rows x 10 columns]

# %%
int_language_score = np.random.randint(1, 100, size=1000)

# %%
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score
# 0                12               0
# 1                44               1
# 2                57               2
# 3                30               3
# 4                85               4
# ..              ...             ...
# 995              24             995
# 996              14             996
# 997              22             997
# 998              83             998
# 999              86             999
#
# [1000 rows x 10 columns]

# %%
np.random.uniform(1,100, size=100)
# Out:
# array([92.67632472, 70.52344739, 76.76490982, 71.50537043, 71.93644363,
#         6.96730484, 92.57288416, 53.97151115, 60.56604838, 46.36723557,
#        39.22517668, 74.71853976, 30.40200473, 55.23738127, 81.23669017,
#        89.94611221, 82.03974837, 59.13843269, 92.54911756, 34.77778942,
#        39.70259253,  2.57014266,  8.85897594, 79.92595392, 96.59058258,
#        35.84791907, 64.01284306,  8.52575626, 55.40328484,  6.67270266,
#         4.2704007 , 31.84823167, 28.72130079, 61.11986687, 76.927987  ,
#        16.26964804, 96.84676164, 36.60212589, 84.16783782, 61.31690612,
#        29.41062163, 16.61201597, 41.39760632, 51.01621579, 60.76388081,
#         8.79034752,  5.74124647, 13.71433243, 28.7039872 , 40.5957056 ,
#        48.27451525, 27.23610584, 19.9829445 , 27.02705534, 19.69550634,
#        61.51712163, 63.4533014 , 96.37143159, 89.62347511, 49.37886504,
#        95.29563352, 79.87200524, 64.70230528,  5.67358191, 63.89543095,
#        44.95288307, 72.38990795,  2.72595279,  8.44606601, 82.77675729,
#        71.220676  , 71.11575486, 64.63578124, 83.65373381, 34.84406419,
#        15.12971061, 91.78531289, 88.87485777, 90.32354894, 64.19456932,
#        42.99067513,  5.25481041,  4.58274269, 77.35147639, 49.15703509,
#        48.17784124, 51.96627582, 17.54809924, 83.14382204, 69.14716212,
#        40.91964202, 49.22511565,  5.66051654, 16.26736091, 32.99552438,
#        11.78103541, 74.92737311, 87.68439419, 21.84703188, 54.13483585])
