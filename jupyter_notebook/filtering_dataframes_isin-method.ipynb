# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv', parse_dates = ['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-03 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-03 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-03 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
condition1 = df['Team'] == 'Legal'
condition2 = df['Team'] == 'Sales'
condition3 = df['Team'] == 'Product'

df[condition1 | condition2 | condition3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-03 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-03 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-03 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-03 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-03 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-03 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-03 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-03 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-03 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-03 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
condition1 = df['Team'].isin(['Legal', 'Sales', 'Product'])
df[condition1]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-03 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-03 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-03 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-03 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-03 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-03 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-03 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-03 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-03 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-03 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]
