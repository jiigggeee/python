# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv', parse_dates = ['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.sort_values('First Name', inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-14 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-14 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-14 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
df.drop_duplicates()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-14 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-14 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-14 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-14 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-03-14 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-14 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-14 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-14 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-14 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-14 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [1000 rows x 8 columns]

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ['First Name'], keep = False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-03-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-03-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-03-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-03-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-03-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-03-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-03-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-03-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-03-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
df.drop_duplicates(subset = ['Team', 'First Name'])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-14 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2022-03-14 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-03-14 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-03-14 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-03-14 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2022-03-14 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2022-03-14 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2022-03-14 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2022-03-14 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2022-03-14 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# 440               True       Client Services
# 137              False          Distribution
# 141               True               Product
# 302               True       Human Resources
# ..                 ...                   ...
# 149               True          Distribution
# 157               True               Product
# 269               True       Human Resources
# 329               True           Engineering
# 481               True  Business Development
#
# [769 rows x 8 columns]
